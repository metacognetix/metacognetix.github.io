# %%
display(dbutils.fs.ls("/databricks-datasets"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/README.md</td><td>README.md</td><td>976</td></tr><tr><td>dbfs:/databricks-datasets/Rdatasets/</td><td>Rdatasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/SPARK_README.md</td><td>SPARK_README.md</td><td>3359</td></tr><tr><td>dbfs:/databricks-datasets/adult/</td><td>adult/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/airlines/</td><td>airlines/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/amazon/</td><td>amazon/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/asa/</td><td>asa/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/atlas_higgs/</td><td>atlas_higgs/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/bikeSharing/</td><td>bikeSharing/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cctvVideos/</td><td>cctvVideos/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/credit-card-fraud/</td><td>credit-card-fraud/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs100/</td><td>cs100/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs110x/</td><td>cs110x/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs190/</td><td>cs190/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/data.gov/</td><td>data.gov/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/</td><td>definitive-guide/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/flights/</td><td>flights/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/genomics/</td><td>genomics/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/hail/</td><td>hail/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/iot/</td><td>iot/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/</td><td>iot-stream/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark/</td><td>learning-spark/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/</td><td>learning-spark-v2/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/lending-club-loan-stats/</td><td>lending-club-loan-stats/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/mnist-digits/</td><td>mnist-digits/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/news20.binary/</td><td>news20.binary/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/online_retail/</td><td>online_retail/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/overlap-join/</td><td>overlap-join/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/power-plant/</td><td>power-plant/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/rwe/</td><td>rwe/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sai-summit-2019-sf/</td><td>sai-summit-2019-sf/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/</td><td>sample_logs/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/samples/</td><td>samples/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sfo_customer_survey/</td><td>sfo_customer_survey/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sms_spam_collection/</td><td>sms_spam_collection/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/songs/</td><td>songs/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/structured-streaming/</td><td>structured-streaming/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/timeseries/</td><td>timeseries/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/tpch/</td><td>tpch/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/weather/</td><td>weather/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/wiki/</td><td>wiki/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/wikipedia-datasets/</td><td>wikipedia-datasets/</td><td>0</td></tr></tbody></table></div>

# %%
selected_dataset = "sample_logs"
selected_dataset_path = "/databricks-datasets/" + selected_dataset

print(selected_dataset_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks-datasets/sample_logs
# </div>

# %%
filelist = dbutils.fs.ls(selected_dataset_path)
display(filelist)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/sample_logs/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00000</td><td>part-00000</td><td>245305</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00001</td><td>part-00001</td><td>245304</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00002</td><td>part-00002</td><td>245337</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00003</td><td>part-00003</td><td>245119</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00004</td><td>part-00004</td><td>245355</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00005</td><td>part-00005</td><td>245462</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00006</td><td>part-00006</td><td>245184</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00007</td><td>part-00007</td><td>245401</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00008</td><td>part-00008</td><td>245305</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00009</td><td>part-00009</td><td>245460</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00010</td><td>part-00010</td><td>245337</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00011</td><td>part-00011</td><td>245119</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00012</td><td>part-00012</td><td>245355</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00013</td><td>part-00013</td><td>245462</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00014</td><td>part-00014</td><td>245184</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00015</td><td>part-00015</td><td>327256</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00016</td><td>part-00016</td><td>245305</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00017</td><td>part-00017</td><td>245340</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00018</td><td>part-00018</td><td>245337</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00019</td><td>part-00019</td><td>245119</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00020</td><td>part-00020</td><td>245355</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00021</td><td>part-00021</td><td>245462</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00022</td><td>part-00022</td><td>245184</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00023</td><td>part-00023</td><td>245401</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00024</td><td>part-00024</td><td>245305</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00025</td><td>part-00025</td><td>245460</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00026</td><td>part-00026</td><td>245337</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00027</td><td>part-00027</td><td>245119</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00028</td><td>part-00028</td><td>245355</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00029</td><td>part-00029</td><td>245462</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00030</td><td>part-00030</td><td>245184</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/part-00031</td><td>part-00031</td><td>299105</td></tr></tbody></table></div>

# %%
from pyspark.sql import *

filelistDF = sqlContext.createDataFrame(filelist)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
just_readme = filelistDF.filter((filelistDF.name == "README.md") | (filelistDF.name == "readme.md"))
display(just_readme)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody></tbody></table></div>

# %%
filelistDF.createOrReplaceTempView("filelist_view")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select `path` from filelist_view where `name` like 'README%'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody></tbody></table></div>

# %%
#print(filelist)
print(filelist[0][1])

with open("/dbfs/" + selected_dataset_path + "/part-00004") as f:
  x = ''.join(f.readlines())
  
print(x)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">_SUCCESS
# 2.2.2.2 - - [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_875 HTTP/1.1&#34; 500 396
# 127.0.0.1 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_314 HTTP/1.1&#34; 200 220
# 4.4.4.4 - user1 [21/Mar/2014:10:00:00 -0400] &#34;PUT /endpoint_996 HTTP/1.1&#34; 200 24
# 3.3.3.3 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_490 HTTP/1.1&#34; 200 107
# 4.4.4.4 - - [21/Jul/2014:10:00:00 -0800] &#34;PUT /endpoint_424 HTTP/1.1&#34; 200 38
# 2.2.2.2 - - [21/May/2014:10:00:00 -0600] &#34;POST /endpoint_222 HTTP/1.1&#34; 200 464
# 3.3.3.3 - - [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_899 HTTP/1.1&#34; 401 429
# 3.3.3.3 - user2 [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_772 HTTP/1.1&#34; 200 461
# 2.2.2.2 - user1 [21/Jan/2014:10:00:00 -0200] &#34;POST /endpoint_710 HTTP/1.1&#34; 401 205
# 3.3.3.3 - user1 [21/Jun/2014:10:00:00 -0700] &#34;POST /endpoint_906 HTTP/1.1&#34; 200 476
# 1.1.1.1 - user1 [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_972 HTTP/1.1&#34; 500 62
# 127.0.0.1 - user1 [21/Jun/2014:10:00:00 -0700] &#34;PUT /endpoint_601 HTTP/1.1&#34; 200 68
# 2.2.2.2 - user1 [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_542 HTTP/1.1&#34; 200 372
# 3.3.3.3 - user1 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_573 HTTP/1.1&#34; 500 251
# 3.3.3.3 - - [21/Jun/2014:10:00:00 -0700] &#34;POST /endpoint_447 HTTP/1.1&#34; 500 417
# 1.1.1.1 - - [21/Jun/2014:10:00:00 -0700] &#34;PUT /endpoint_405 HTTP/1.1&#34; 401 231
# 1.1.1.1 - - [21/Jul/2014:10:00:00 -0800] &#34;PUT /endpoint_751 HTTP/1.1&#34; 401 150
# 4.4.4.4 - user1 [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_805 HTTP/1.1&#34; 200 78
# 2.2.2.2 - - [21/May/2014:10:00:00 -0600] &#34;PUT /endpoint_998 HTTP/1.1&#34; 200 276
# 3.3.3.3 - - [21/Jul/2014:10:00:00 -0800] &#34;POST /endpoint_479 HTTP/1.1&#34; 500 308
# 3.3.3.3 - user2 [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_956 HTTP/1.1&#34; 200 382
# 127.0.0.1 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_349 HTTP/1.1&#34; 200 116
# 127.0.0.1 - user2 [21/Jan/2014:10:00:00 -0200] &#34;PUT /endpoint_315 HTTP/1.1&#34; 200 176
# 4.4.4.4 - - [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_625 HTTP/1.1&#34; 200 385
# 3.3.3.3 - - [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_565 HTTP/1.1&#34; 401 295
# 2.2.2.2 - user2 [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_65 HTTP/1.1&#34; 200 168
# 3.3.3.3 - user1 [21/Mar/2014:10:00:00 -0400] &#34;PUT /endpoint_671 HTTP/1.1&#34; 200 194
# 3.3.3.3 - - [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_606 HTTP/1.1&#34; 200 271
# 4.4.4.4 - - [21/Jan/2014:10:00:00 -0200] &#34;PUT /endpoint_40 HTTP/1.1&#34; 500 129
# 2.2.2.2 - - [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_698 HTTP/1.1&#34; 200 196
# 4.4.4.4 - - [21/Jan/2014:10:00:00 -0200] &#34;PUT /endpoint_675 HTTP/1.1&#34; 500 284
# 4.4.4.4 - user1 [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_113 HTTP/1.1&#34; 200 273
# 1.1.1.1 - - [21/Feb/2014:10:00:00 -0300] &#34;PUT /endpoint_805 HTTP/1.1&#34; 500 18
# 3.3.3.3 - - [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_375 HTTP/1.1&#34; 200 292
# 127.0.0.1 - user1 [21/Jan/2014:10:00:00 -0200] &#34;POST /endpoint_539 HTTP/1.1&#34; 200 404
# 2.2.2.2 - user1 [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_471 HTTP/1.1&#34; 200 354
# 3.3.3.3 - - [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_341 HTTP/1.1&#34; 500 220
# 3.3.3.3 - user1 [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_396 HTTP/1.1&#34; 200 289
# 3.3.3.3 - user2 [21/Feb/2014:10:00:00 -0300] &#34;POST /endpoint_586 HTTP/1.1&#34; 200 473
# 4.4.4.4 - - [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_38 HTTP/1.1&#34; 500 142
# 3.3.3.3 - user2 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_689 HTTP/1.1&#34; 500 64
# 3.3.3.3 - - [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_43 HTTP/1.1&#34; 200 178
# 1.1.1.1 - - [21/Jun/2014:10:00:00 -0700] &#34;PUT /endpoint_946 HTTP/1.1&#34; 200 80
# 2.2.2.2 - user2 [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_118 HTTP/1.1&#34; 200 423
# 1.1.1.1 - - [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_56 HTTP/1.1&#34; 200 240
# 127.0.0.1 - - [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_452 HTTP/1.1&#34; 500 315
# 3.3.3.3 - - [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_318 HTTP/1.1&#34; 200 314
# 127.0.0.1 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_30 HTTP/1.1&#34; 200 362
# 1.1.1.1 - - [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_152 HTTP/1.1&#34; 401 288
# 2.2.2.2 - user2 [21/Jan/2014:10:00:00 -0200] &#34;PUT /endpoint_612 HTTP/1.1&#34; 200 153
# 4.4.4.4 - user2 [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_378 HTTP/1.1&#34; 500 387
# 1.1.1.1 - user2 [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_876 HTTP/1.1&#34; 200 46
# 127.0.0.1 - - [21/Jul/2014:10:00:00 -0800] &#34;POST /endpoint_921 HTTP/1.1&#34; 200 400
# 127.0.0.1 - user2 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_935 HTTP/1.1&#34; 200 386
# 2.2.2.2 - user2 [21/Jan/2014:10:00:00 -0200] &#34;PUT /endpoint_917 HTTP/1.1&#34; 200 443
# 3.3.3.3 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_752 HTTP/1.1&#34; 200 324
# 127.0.0.1 - - [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_191 HTTP/1.1&#34; 200 170
# 4.4.4.4 - user1 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_91 HTTP/1.1&#34; 200 72
# 2.2.2.2 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_955 HTTP/1.1&#34; 200 276
# 2.2.2.2 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_431 HTTP/1.1&#34; 200 64
# 3.3.3.3 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_496 HTTP/1.1&#34; 401 149
# 3.3.3.3 - - [21/Jan/2014:10:00:00 -0200] &#34;PUT /endpoint_791 HTTP/1.1&#34; 500 387
# 127.0.0.1 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_500 HTTP/1.1&#34; 200 359
# 3.3.3.3 - - [21/Mar/2014:10:00:00 -0400] &#34;POST /endpoint_166 HTTP/1.1&#34; 200 269
# 4.4.4.4 - - [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_266 HTTP/1.1&#34; 401 390
# 2.2.2.2 - user2 [21/Jan/2014:10:00:00 -0200] &#34;PUT /endpoint_195 HTTP/1.1&#34; 200 314
# 3.3.3.3 - - [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_69 HTTP/1.1&#34; 200 31
# 1.1.1.1 - user2 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_175 HTTP/1.1&#34; 401 187
# 4.4.4.4 - - [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_915 HTTP/1.1&#34; 200 160
# 127.0.0.1 - user2 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_707 HTTP/1.1&#34; 200 136
# 1.1.1.1 - user2 [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_553 HTTP/1.1&#34; 500 185
# 4.4.4.4 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_967 HTTP/1.1&#34; 200 371
# 4.4.4.4 - user1 [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_286 HTTP/1.1&#34; 200 498
# 4.4.4.4 - user2 [21/Jun/2014:10:00:00 -0700] &#34;POST /endpoint_234 HTTP/1.1&#34; 500 110
# 1.1.1.1 - user1 [21/May/2014:10:00:00 -0600] &#34;PUT /endpoint_497 HTTP/1.1&#34; 401 493
# 3.3.3.3 - user1 [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_525 HTTP/1.1&#34; 200 260
# 4.4.4.4 - - [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_869 HTTP/1.1&#34; 401 470
# 1.1.1.1 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_606 HTTP/1.1&#34; 200 129
# 3.3.3.3 - - [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_745 HTTP/1.1&#34; 200 257
# 1.1.1.1 - - [21/Jan/2014:10:00:00 -0200] &#34;PUT /endpoint_947 HTTP/1.1&#34; 200 390
# 4.4.4.4 - - [21/Apr/2014:10:00:00 -0500] &#34;POST /endpoint_440 HTTP/1.1&#34; 200 279
# 4.4.4.4 - user1 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_911 HTTP/1.1&#34; 200 315
# 1.1.1.1 - user1 [21/May/2014:10:00:00 -0600] &#34;PUT /endpoint_683 HTTP/1.1&#34; 200 413
# 4.4.4.4 - - [21/Jul/2014:10:00:00 -0800] &#34;POST /endpoint_753 HTTP/1.1&#34; 200 397
# 4.4.4.4 - user1 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_593 HTTP/1.1&#34; 500 389
# 4.4.4.4 - user1 [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_159 HTTP/1.1&#34; 200 94
# 4.4.4.4 - user2 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_836 HTTP/1.1&#34; 200 463
# 1.1.1.1 -

# %%
 export_json = filelistDF.toJSON()
print(export_json.take(2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;{&#34;path&#34;:&#34;dbfs:/databricks-datasets/sample_logs/_SUCCESS&#34;,&#34;name&#34;:&#34;_SUCCESS&#34;,&#34;size&#34;:0}&#39;, &#39;{&#34;path&#34;:&#34;dbfs:/databricks-datasets/sample_logs/part-00000&#34;,&#34;name&#34;:&#34;part-00000&#34;,&#34;size&#34;:245305}&#39;]
# </div>

# %%
import re
from pyspark.sql import Row

apache_access_log_format = '^(\S+) (\S+) (\S+) \[([\w:/]+\s[+\-]\d{4})\] "(\S+) (\S+) (\S+)" (\d{3}) (\d+)'

#Return a dictionary containing the parts of the Apache access log
def parse_apache_log_line(line):
  match = re.search(apache_access_log_format, line)
  if match is None:
    # Might want to just ignore, since it'a common to have dirty logs
    raise Error("Invalid log line format: %s" % line)
  return Row(
    ipAddress = match.group(1),
    clientIdentd = match.group(2),
    userId = match.group(3),
    dateTime = match.group(4),
    method = match.group(5),
    endpoint = match.group(6),
    protocol = match.group(7),
    responseCode = int(match.group(8)),
    contentSize = long(match.group(9)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
logfileload = sc.textfile(selected_dataset_path + "/part-00004")
#accesslogs = (sc.textfile(selected_dataset_path + "/part-00004").map(parse_apache_log_line).cache())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1870396156020955&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>logfileload <span class="ansi-blue-fg">=</span> sc<span class="ansi-blue-fg">.</span>textfile<span class="ansi-blue-fg">(</span>selected_dataset_path <span class="ansi-blue-fg">+</span> <span class="ansi-blue-fg">&#34;/part-00004&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> <span class="ansi-red-fg">#accesslogs = (sc.textfile(selected_dataset_path + &#34;/part-00004&#34;).map(parse_apache_log_line).cache())</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;RemoteContext&#39; object has no attribute &#39;textfile&#39;</div>
